# %%
import sys
sys.path.append('..')
from compiler.Graph import *
from compiler.QTree import *
from perceval.rendering.circuit import SymbSkin #just a compact skin
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import random
random.seed(134)
t = random_tree(4)
# Out:
# 0 1
# 1 2
# 0 3

# %%
#build a new Quantum Tree
q = QTree(t.head.value)
#print the number of outer circles needed to implement this tree with optimal bfs
print(build_optimal(t.head, q))
# Out:
# 4

# %%
expand = [(t.head,0)]
while expand:
    vertex,depth = expand.pop()
    print(" "*(4*(depth-1))+("|---" if depth > 0 else "")+str(vertex.value))
    for child in vertex.children:
        expand.append((child, depth+1))
# Out:
# 0
# |---1
#     |---2
# |---3

# %%
pcvl.pdisplay(q.loop.circuit)

# %%
q.loop.circuit._components[5][1].__dict__
# Out:
# {'_m': 2,
#  '_name': None,
#  '_params': {'theta': Parameter(name='theta', value=3.141592653589793, min_v=0.0, max_v=12.566370614359172),
#   'phi_tl': Parameter(name='phi_tl', value=0, min_v=0.0, max_v=6.283185307179586),
#   'phi_bl': Parameter(name='phi_bl', value=0, min_v=0.0, max_v=6.283185307179586),
#   'phi_tr': Parameter(name='phi_tr', value=0, min_v=0.0, max_v=6.283185307179586),
#   'phi_br': Parameter(name='phi_br', value=0, min_v=0.0, max_v=6.283185307179586)},
#  '_vars': {},
#  '_convention': <BSConvention.H: 2>,
#  '_theta': Parameter(name='theta', value=3.141592653589793, min_v=0.0, max_v=12.566370614359172),
#  '_phi_tl': Parameter(name='phi_tl', value=0, min_v=0.0, max_v=6.283185307179586),
#  '_phi_bl': Parameter(name='phi_bl', value=0, min_v=0.0, max_v=6.283185307179586),
#  '_phi_tr': Parameter(name='phi_tr', value=0, min_v=0.0, max_v=6.283185307179586),
#  '_phi_br': Parameter(name='phi_br', value=0, min_v=0.0, max_v=6.283185307179586),
#  '_x_grid': None}

# %%
q.loop.circuit._components[9][1].__dict__
# Out:
# {'_m': 2,
#  '_name': None,
#  '_params': {'theta': Parameter(name='theta', value=pi/2, min_v=0.0, max_v=12.566370614359172),
#   'phi_tl': Parameter(name='phi_tl', value=0, min_v=0.0, max_v=6.283185307179586),
#   'phi_bl': Parameter(name='phi_bl', value=0, min_v=0.0, max_v=6.283185307179586),
#   'phi_tr': Parameter(name='phi_tr', value=0, min_v=0.0, max_v=6.283185307179586),
#   'phi_br': Parameter(name='phi_br', value=0, min_v=0.0, max_v=6.283185307179586)},
#  '_vars': {},
#  '_convention': <BSConvention.H: 2>,
#  '_theta': Parameter(name='theta', value=pi/2, min_v=0.0, max_v=12.566370614359172),
#  '_phi_tl': Parameter(name='phi_tl', value=0, min_v=0.0, max_v=6.283185307179586),
#  '_phi_bl': Parameter(name='phi_bl', value=0, min_v=0.0, max_v=6.283185307179586),
#  '_phi_tr': Parameter(name='phi_tr', value=0, min_v=0.0, max_v=6.283185307179586),
#  '_phi_br': Parameter(name='phi_br', value=0, min_v=0.0, max_v=6.283185307179586),
#  '_x_grid': None}
